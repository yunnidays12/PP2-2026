# %% [markdown]
# ## My project
# - 작성일 : 2026.09.08
# - 작성자 : 김윤성
#     - 컴퓨터공학과 복수전공
#     - 수학교육과 2학년

# %%
print("hello, My project!")
# Out:
# hello, My project!

# %% [markdown]
# 이 알고리즘은 아주 간단합니다.
# 백트래킹 알고리즘을 사용하였으며, 동적계획법을 이용하였습니다.
