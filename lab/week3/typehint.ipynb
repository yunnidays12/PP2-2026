# %% [markdown]
# ### Typehint 연습
#
# 이 파일은 파이썬의 typehint 예제와 이론을 다루는 노트입니다.
# * 작성자 : 김윤성
# * 작성일자 : 2026.09.15
#
#     * 타입힌트는 함수의 매개변수와 반환값의 타입을 지정하는 목적으로 사용한다.
#     * 엄격한 타입지정으로 인한 프로그래머의 의도를 명확히 전달하기 위함이다.
#     * 안써도 되지만, 파이썬 13부터는 쓰는 것을 권고하고 있다.

# %%
#타입힌트가 없는 경우

def greet(msg) :
    print("In greet : ", msg)
    return msg + "!"

print(greet("안녕"))
# Out:
# 안녕!

# %%
#타입힌트가 있는 경우

def greet(msg:str) -> str : #msg도 str 타입이고, return도 str 타입이다.
    print("In greet : ", msg)
    return msg + "!"

print(greet("안녕"))
print(greet(3.141592)) 

#[출력결과] TypeError: unsupported operand type(s) for +: 'float' and 'str'
#[오류원인] msg를 str 타입으로 주지 않아서 오류 발생.
# Out:
# In greet :  안녕
# 안녕!
# In greet :  3.141592
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       4     print("In greet : ", msg)
#       5     return msg + "!"
#       6
#       7 print(greet("안녕"))
# ----> 8 print(greet(3.141592)) #출력결과 :
#
# Cell In[2], line 5, in greet(msg)
#       3 def greet(msg:str) -> str : #msg도 str 타입이고, return도 str 타입이다.
#       4     print("In greet : ", msg)
# ----> 5     return msg + "!"
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
